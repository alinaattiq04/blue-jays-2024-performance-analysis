# %%
import pandas as pd
import numpy as np

# %%
import os
os.listdir('/content')
# Out:
# ['.config',
#  'bluejays_batting_2024_raw - bluejays_batting_2024_raw.csv',
#  '.ipynb_checkpoints',
#  'sample_data']

# %%
df = pd.read_csv('bluejays_batting_2024_raw.csv')
